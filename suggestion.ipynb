# %%
import pandas as pd
import glob
import dask.dataframe as dd

# %%
data = pd.read_csv(r'C:\Users\ty_ma\repository\IR-Project\Clean-Data-01.txt', sep="\t", header=None)
data.columns = ["session_id", "query", "datetime"]
len(data)

data2 = pd.read_csv(r'C:\Users\ty_ma\repository\IR-Project\Clean-Data-02.txt', sep="\t", header=None)
data2.columns = ["session_id", "query", "datetime"]
len(data2)

data3 = pd.read_csv(r'C:\Users\ty_ma\repository\IR-Project\Clean-Data-03.txt', sep="\t", header=None)
data3.columns = ["session_id", "query", "datetime"]
len(data3)

data4 = pd.read_csv(r'C:\Users\ty_ma\repository\IR-Project\Clean-Data-04.txt', sep="\t", header=None)
data4.columns = ["session_id", "query", "datetime"]
len(data4)

data5 = pd.read_csv(r'C:\Users\ty_ma\repository\IR-Project\Clean-Data-05.txt', sep="\t", header=None)
data5.columns = ["session_id", "query", "datetime"]
len(data5)
# Out:
# 834358

# %%
print(len(data))
print(len(data2))
print(len(data3))
print(len(data4))
print(len(data5))
# Out:
# 761993
# 773892
# 791029
# 781087
# 834358

# %%
data = data.append(data2)
data = data.append(data3)
data = data.append(data4)
data = data.append(data5)

# %%
print(len(data))
# Out:
# 3942359

# %%
data[:5]
data.drop(data.index[0])
# Out:
#        session_id                                              query  \
# 1             142                           merit release appearance
# 2             217                                            lottery
# 3             217                                            lottery
# 4             217                                            vietnam
# 5             217                                            vietnam
# 6            1268                                        gall stones
# 7            1268                                         gallstones
# 8            1326                                              files
# 9            1326                                        pop up adds
# 10           1326                                        pop up adds
# 11           1326                      the childs wonderland company
# 12           1326                     the child's wonderland company
# 13           1326                     the child's wonderland company
# 14           1326  the child's wonderland company grand rapids mi...
# 15           1326                                budget truck rental
# 16           1326                          holiday mansion houseboat
# 17           1326                                 back to the future
# 18           1326                          holiday mansion houseboat
# 19           1326                      the childs wonderland company
# 20           1326                                  jet blue airlines
# 21           1337                           select business services
# 22           1337                     select business services title
# 23           1337                                      cbc companies
# 24           1337           national real estate settlement services
# 25           1337       pennsylvania real estate settlement services
# 26           1337       pennsylvania real estate settlement services
# 27           1337       chesapeake appraisal and settlement services
# 28           1337                   first american lenders advantage
# 29           1337                          first american chesapeake
# 30           1337           first american chesapeake title services
# ...           ...                                                ...
# 834328   24949536                                poland spring water
# 834329   24949536                                poland spring water
# 834330   24949536                                poland spring water
# 834331   24950004                                             google
# 834332   24951220                                           my space
# 834333   24954268                                       win for life
# 834334   24955108                                          odd gifts
# 834335   24955108                              elegant gifts for her
# 834336   24956559                                          used cars
# 834337   24956559                                    kelly blue book
# 834338   24956559                                    kelly blue book
# 834339   24956559                                    kelly blue book
# 834340   24956559                                    kelly blue book
# 834341   24956559                                    kelly blue book
# 834342   24956559                              long beach acceptance
# 834343   24958822                                        clenbuterol
# 834344   24960115                                        nys lottery
# 834345   24960115                                      mega millions
# 834346   24962214                           anderson county jail cam
# 834347   24962262                                      omega psi phi
# 834348   24962433                                   lotions and lace
# 834349   24962433                                    rabbit vibrator
# 834350   24962433                                    rabbit vibrator
# 834351   24962537                                        chap hotels
# 834352   24963973                                   clergy vestments
# 834353   24963973              united church of christ clergy stoles
# 834354   24963973                      national cathedral gift store
# 834355   24965114                                            weather
# 834356   24965131                                         dictionary
# 834357   24967039                                 vienna state opera
#
#                    datetime
# 1       2006-04-22 23:51:18
# 2       2006-03-01 11:58:51
# 3       2006-03-27 14:10:38
# 4       2006-05-22 17:43:42
# 5       2006-05-22 18:03:24
# 6       2006-05-11 02:12:51
# 7       2006-05-11 02:13:02
# 8       2006-03-01 17:36:08
# 9       2006-03-15 20:07:38
# 10      2006-03-15 20:08:29
# 11      2006-03-21 11:50:10
# 12      2006-03-21 11:59:03
# 13      2006-03-21 12:00:55
# 14      2006-03-21 12:01:24
# 15      2006-03-24 18:27:07
# 16      2006-03-29 17:14:01
# 17      2006-04-01 17:59:28
# 18      2006-04-06 20:20:43
# 19      2006-04-11 17:25:27
# 20      2006-04-27 15:29:05
# 21      2006-03-14 15:51:41
# 22      2006-03-14 15:52:10
# 23      2006-03-14 15:52:44
# 24      2006-03-14 15:59:13
# 25      2006-03-14 16:04:40
# 26      2006-03-14 16:05:11
# 27      2006-03-15 13:51:52
# 28      2006-03-22 16:05:56
# 29      2006-03-22 16:11:31
# 30      2006-03-22 16:11:50
# ...                     ...
# 834328  2006-05-31 07:33:44
# 834329  2006-05-31 07:57:44
# 834330  2006-05-31 08:17:54
# 834331  2006-05-31 20:56:12
# 834332  2006-05-31 00:39:58
# 834333  2006-05-31 09:44:12
# 834334  2006-05-31 06:47:27
# 834335  2006-05-31 06:56:10
# 834336  2006-05-31 09:21:53
# 834337  2006-05-31 14:05:12
# 834338  2006-05-31 14:23:07
# 834339  2006-05-31 14:36:23
# 834340  2006-05-31 14:48:57
# 834341  2006-05-31 15:45:57
# 834342  2006-05-31 21:35:03
# 834343  2006-05-31 03:58:10
# 834344  2006-05-31 13:15:09
# 834345  2006-05-31 13:16:25
# 834346  2006-05-31 18:05:23
# 834347  2006-05-31 01:27:11
# 834348  2006-05-31 02:30:10
# 834349  2006-05-31 02:31:46
# 834350  2006-05-31 02:33:06
# 834351  2006-05-31 17:44:50
# 834352  2006-05-31 21:18:12
# 834353  2006-05-31 21:54:09
# 834354  2006-05-31 21:58:42
# 834355  2006-05-31 21:17:04
# 834356  2006-05-31 22:34:16
# 834357  2006-05-31 13:59:45
#
# [3942354 rows x 3 columns]

# %%
data = data.drop([0])

# %%
data[:5]
# Out:
#   session_id                     query             datetime
# 1        142  merit release appearance  2006-04-22 23:51:18
# 2        217                   lottery  2006-03-01 11:58:51
# 3        217                   lottery  2006-03-27 14:10:38
# 4        217                   vietnam  2006-05-22 17:43:42
# 5        217                   vietnam  2006-05-22 18:03:24

# %%
data.groupby('session_id')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-42-61909a1e9368> in <module>
# ----> 1 data.groupby('session_id')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    7630         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    7631                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 7632                        observed=observed, **kwargs)
#    7633
#    7634     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2108         raise TypeError('invalid type: {}'.format(obj))
#    2109
# -> 2110     return klass(obj, by, **kwds)
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     333
#     334         if isinstance(obj, NDFrame):
# --> 335             obj._consolidate_inplace()
#     336
#     337         self.level = level
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _consolidate_inplace(self)
#    5136             self._data = self._data.consolidate()
#    5137
# -> 5138         self._protect_consolidate(f)
#    5139
#    5140     def _consolidate(self, inplace=False):
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _protect_consolidate(self, f)
#    5125         """
#    5126         blocks_before = len(self._data.blocks)
# -> 5127         result = f()
#    5128         if len(self._data.blocks) != blocks_before:
#    5129             self._clear_item_cache()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in f()
#    5134
#    5135         def f():
# -> 5136             self._data = self._data.consolidate()
#    5137
#    5138         self._protect_consolidate(f)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in consolidate(self)
#     922         bm = self.__class__(self.blocks, self.axes)
#     923         bm._is_consolidated = False
# --> 924         bm._consolidate_inplace()
#     925         return bm
#     926
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _consolidate_inplace(self)
#     927     def _consolidate_inplace(self):
#     928         if not self.is_consolidated():
# --> 929             self.blocks = tuple(_consolidate(self.blocks))
#     930             self._is_consolidated = True
#     931             self._known_consolidated = True
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in _consolidate(blocks)
#    1897     for (_can_consolidate, dtype), group_blocks in grouper:
#    1898         merged_blocks = _merge_blocks(list(group_blocks), dtype=dtype,
# -> 1899                                       _can_consolidate=_can_consolidate)
#    1900         new_blocks = _extend_blocks(merged_blocks, new_blocks)
#    1901     return new_blocks
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in _merge_blocks(blocks, dtype, _can_consolidate)
#    3144         # combination of those slices is a slice, too.
#    3145         new_mgr_locs = np.concatenate([b.mgr_locs.as_array for b in blocks])
# -> 3146         new_values = np.vstack([b.values for b in blocks])
#    3147
#    3148         argsort = np.argsort(new_mgr_locs)
#
# ~\Anaconda3\lib\site-packages\numpy\core\shape_base.py in vstack(tup)
#     281     """
#     282     _warn_for_nonsequence(tup)
# --> 283     return _nx.concatenate([atleast_2d(_m) for _m in tup], 0)
#     284
#     285
#
# MemoryError:
